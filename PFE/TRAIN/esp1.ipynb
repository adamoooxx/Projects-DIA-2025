# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# Style des graphiques
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Remplace par le bon chemin si besoin
df = pd.read_csv("DATA/TRAIN.csv", delimiter=';')
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (9539, 16)
#    FID_1  Annee     Saison     LAT_DD     LONG_DD    LAT_CSV    LONG_CSV  \
# 0      4   2020  printemps  31,842500  -10,969440  31,842500  -10,969440
# 1      0   2020  printemps  31,872778  -10,167222  31,872778  -10,167222
# 2      1   2020  printemps  31,877500  -10,185833  31,877500  -10,185833
# 3      2   2020  printemps  31,857778  -10,132222  31,857778  -10,132222
# 4      3   2020  printemps  31,865556  -10,149444  31,865556  -10,149444
#
#     Esp1  Pres_Esp1     Esp2  Pres_Esp2   Salinite       Temp        DO  \
# 0  0,000          0    41,55          1  36,250000  18,410000  5,101000
# 1  0,000          0  2661,05          1  36,240000  18,300000  5,113000
# 2  0,000          0  1338,63          1  36,224000  18,530000  5,192000
# 3  0,000          0   416,55          1  36,239000  18,140000  5,112000
# 4  0,000          0   363,64          1  36,227000  18,260000  5,142000
#
#          pH LABEL
# 0  7,910000  CY49
# 1  7,949800  DC49
# 2  7,918200  DC49
# 3  7,949900  DD49
# 4  7,949600  DD49

# %%
print("\nTypes de données :")
print(df.dtypes)

print("\nValeurs manquantes :")
print(df.isnull().sum())

# Visualisation des valeurs manquantes
msno.matrix(df)
plt.title("Valeurs manquantes")
plt.show()
# Out:
# Types de données :
# FID_1         int64
# Annee         int64
# Saison       object
# LAT_DD       object
# LONG_DD      object
# LAT_CSV      object
# LONG_CSV     object
# Esp1         object
# Pres_Esp1     int64
# Esp2         object
# Pres_Esp2     int64
# Salinite     object
# Temp         object
# DO           object
# pH           object
# LABEL        object
# dtype: object
#
# Valeurs manquantes :
# FID_1         0
# Annee         0
# Saison        0
# LAT_DD        0
# LONG_DD       0
# LAT_CSV       0
# LONG_CSV      0
# Esp1          0
# Pres_Esp1     0
# Esp2          0
# Pres_Esp2     0
# Salinite      0
# Temp          0
# DO            0
# pH            0
# LABEL        12
# dtype: int64

# %%
# Colonnes à convertir (modifie selon les noms dans ton dataset)
num_cols = ['LONG_DD', 'LAT_DD', 'Salinite', 'Temp', 'DO', 'pH']

for col in num_cols:
    if df[col].dtype == 'object':
        df[col] = df[col].str.replace(',', '.').astype(float)

# %%
df[num_cols].describe()
# Out:
#            LONG_DD       LAT_DD     Salinite         Temp           DO  \
# count  9539.000000  9539.000000  9539.000000  9539.000000  9539.000000
# mean    -12.820209    27.905132    36.176633    19.704182     5.065859
# std       3.406915     4.000431     0.222432     0.753940     0.096434
# min     -17.994440    20.894722    35.700000    17.030000     4.900000
# 25%     -15.971806    24.597360    36.229000    19.230000     5.004000
# 50%     -13.179444    28.100833    36.244000    19.630000     5.095000
# 75%      -9.931389    30.938195    36.332000    20.380000     5.115000
# max      -5.920556    35.997220    36.355000    21.870000     5.299000
#
#                 pH
# count  9539.000000
# mean      7.928019
# std       0.060297
# min       7.779400
# 25%       7.919600
# 50%       7.949600
# 75%       7.979500
# max       7.979900

# %%
target = 'Pres_Esp1'

print("\nDistribution de la cible :")
print(df[target].value_counts())
print(df[target].value_counts(normalize=True))

# Affichage
sns.countplot(x=target, data=df)
plt.title("Répartition des classes")
plt.show()
# Out:
# Distribution de la cible :
# Pres_Esp1
# 0    5133
# 1    4406
# Name: count, dtype: int64
# Pres_Esp1
# 0    0.538107
# 1    0.461893
# Name: proportion, dtype: float64

# %%
corr = df[num_cols].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title("Matrice de corrélation")
plt.show()

# %%
for col in num_cols:
    sns.boxplot(x=target, y=col, data=df)
    plt.title(f"{col} par classe")
    plt.show()

# %%
sns.pairplot(df[num_cols + [target]], hue=target)
plt.suptitle("Relations entre les variables", y=1.02)
plt.show()

# %%
# Variables explicatives
features = ['LAT_DD', 'LONG_DD', 'Salinite', 'Temp', 'DO', 'pH']
X = df[features]

# Variable cible
y = df['Pres_Esp1']

# %%
from sklearn.model_selection import train_test_split

# On conserve la proportion des classes avec stratify
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

print("Taille train :", X_train.shape)
print("Taille test  :", X_test.shape)
# Out:
# Taille train : (6677, 6)
# Taille test  : (2862, 6)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# Vérification des nouvelles classes
print("Distribution après SMOTE :")
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Distribution après SMOTE :
# Pres_Esp1
# 0    3593
# 1    3593
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import (
    classification_report, confusion_matrix, 
    roc_auc_score, f1_score, balanced_accuracy_score
)
from imblearn.pipeline import Pipeline as ImbPipeline

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(random_state=42),
    "SVM": SVC(probability=True, random_state=42),
    "KNN": KNeighborsClassifier(),
    "XGBoost": XGBClassifier(random_state=42)
}

# %%
results = []

for name, model in models.items():
    # Pipeline avec SMOTE
    pipeline = ImbPipeline([
        ('smote', SMOTE(random_state=42)),
        ('model', model)
    ])
    
    # Validation croisée
    cv_scores = cross_val_score(pipeline, X_train_scaled, y_train, cv=5, scoring='accuracy')
    
    # Entraînement
    pipeline.fit(X_train_scaled, y_train)
    
    # Prédictions
    y_pred = pipeline.predict(X_test_scaled)
    y_prob = pipeline.predict_proba(X_test_scaled)[:, 1]
    
    # Métriques
    f1 = f1_score(y_test, y_pred)
    bal_acc = balanced_accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)
    
    results.append({
        'Model': name,
        'CV Accuracy Mean': np.mean(cv_scores),
        'CV Accuracy Std': np.std(cv_scores),
        'F1 Score': f1,
        'Balanced Accuracy': bal_acc,
        'ROC AUC': roc_auc
    })
    
    # Rapport
    print(f"\n📊 {name} :")
    print(classification_report(y_test, y_pred))
    
    # Matrice de confusion
    cm = confusion_matrix(y_test, y_pred)
    plt.figure()
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{name} - Matrice de Confusion')
    plt.xlabel('Prédits')
    plt.ylabel('Réels')
    plt.show()
# Out:
# 📊 Logistic Regression :
#               precision    recall  f1-score   support
#
#            0       0.71      0.64      0.67      1540
#            1       0.62      0.69      0.65      1322
#
#     accuracy                           0.66      2862
#    macro avg       0.67      0.67      0.66      2862
# weighted avg       0.67      0.66      0.66      2862
# 📊 Random Forest :
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      1540
#            1       0.87      0.84      0.85      1322
#
#     accuracy                           0.87      2862
#    macro avg       0.87      0.87      0.87      2862
# weighted avg       0.87      0.87      0.87      2862
# 📊 SVM :
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75      1540
#            1       0.70      0.72      0.71      1322
#
#     accuracy                           0.73      2862
#    macro avg       0.73      0.73      0.73      2862
# weighted avg       0.73      0.73      0.73      2862
# 📊 KNN :
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78      1540
#            1       0.74      0.77      0.76      1322
#
#     accuracy                           0.77      2862
#    macro avg       0.77      0.77      0.77      2862
# weighted avg       0.77      0.77      0.77      2862
# 📊 XGBoost :
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      1540
#            1       0.83      0.82      0.83      1322
#
#     accuracy                           0.84      2862
#    macro avg       0.84      0.84      0.84      2862
# weighted avg       0.84      0.84      0.84      2862

# %%
results_df = pd.DataFrame(results)
results_df_sorted = results_df.sort_values(by='ROC AUC', ascending=False)
print("🔝 Résultats Comparatifs :")
print(results_df_sorted)
# Out:
# 🔝 Résultats Comparatifs :
#                  Model  CV Accuracy Mean  CV Accuracy Std  F1 Score  \
# 1        Random Forest          0.836453         0.005334  0.854826
# 4              XGBoost          0.821626         0.006279  0.826718
# 3                  KNN          0.738651         0.012064  0.756034
# 2                  SVM          0.713643         0.008570  0.713485
# 0  Logistic Regression          0.659728         0.015151  0.654689
#
#    Balanced Accuracy   ROC AUC
# 1           0.866411  0.937758
# 4           0.839801  0.919215
# 3           0.770412  0.836616
# 2           0.731325  0.795629
# 0           0.665982  0.727937

# %%
# Trouver le meilleur modèle selon le ROC AUC
best_model_name = results_df_sorted.iloc[0]['Model']
print(f"✅ Meilleur modèle sélectionné : {best_model_name}")
# Out:
# ✅ Meilleur modèle sélectionné : Random Forest

# %%
# Grilles personnalisées selon le modèle
if best_model_name == "Random Forest":
    param_grid = {
        'model__n_estimators': [100, 200, 300],
        'model__max_depth': [10, 20, None],
        'model__min_samples_split': [2, 5, 10],
        'model__min_samples_leaf': [1, 2, 4],
        'model__bootstrap': [True, False]
    }
elif best_model_name == "XGBoost":
    param_grid = {
        'model__n_estimators': [100, 200],
        'model__max_depth': [3, 6, 9],
        'model__learning_rate': [0.01, 0.1, 0.2],
        'model__subsample': [0.8, 1.0],
        'model__colsample_bytree': [0.8, 1.0]
    }
elif best_model_name == "SVM":
    param_grid = {
        'model__C': [0.1, 1, 10],
        'model__kernel': ['linear', 'rbf'],
        'model__gamma': ['scale', 'auto']
    }
elif best_model_name == "Logistic Regression":
    param_grid = {
        'model__C': [0.1, 1, 10],
        'model__penalty': ['l2'],
        'model__solver': ['lbfgs', 'liblinear']
    }
elif best_model_name == "KNN":
    param_grid = {
        'model__n_neighbors': [3, 5, 7, 9],
        'model__weights': ['uniform', 'distance'],
        'model__p': [1, 2]
    }

# %%
# Pipeline avec SMOTE
pipeline = ImbPipeline([
    ('smote', SMOTE(random_state=42)),
    ('model', models[best_model_name])
])

# GridSearch
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train_scaled, y_train)
best_pipeline = grid_search.best_estimator_

print("✅ Meilleurs hyperparamètres :")
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# ✅ Meilleurs hyperparamètres :
# {'model__bootstrap': False, 'model__max_depth': None, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}

# %%
y_pred = best_pipeline.predict(X_test_scaled)
y_prob = best_pipeline.predict_proba(X_test_scaled)[:, 1]

print("\n📋 Rapport final :")
print(classification_report(y_test, y_pred))

# Matrice de confusion
cm = confusion_matrix(y_test, y_pred)
plt.figure()
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matrice de confusion - Modèle final')
plt.xlabel('Prédits')
plt.ylabel('Réels')
plt.show()

# ROC AUC
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.title('Courbe ROC')
plt.xlabel('Taux de faux positifs')
plt.ylabel('Taux de vrais positifs')
plt.legend()
plt.show()
# Out:
# 📋 Rapport final :
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      1540
#            1       0.88      0.84      0.86      1322
#
#     accuracy                           0.87      2862
#    macro avg       0.87      0.87      0.87      2862
# weighted avg       0.87      0.87      0.87      2862

# %%
import joblib

# Sauvegarde du pipeline complet (prétraitement + modèle)
joblib.dump(best_pipeline, 'meilleur_modele_pipeline.pkl')

# Sauvegarde du scaler séparément (optionnel)
joblib.dump(scaler, 'scaler.pkl') 

print("Modèle sauvegardé avec succès !")
# Out:
# Modèle sauvegardé avec succès !

# %%
import torch
import torchvision
print("Torch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
# Out:
# Torch: 2.7.0+cpu
# Torchvision: 0.22.0+cpu

# %%
! pip uninstall torch torchvision -y
! pip install torch==2.6.0 torchvision==0.21.0 --index-url https://download.pytorch.org/whl/cpu
# Out:
# Found existing installation: torch 2.7.0
# Uninstalling torch-2.7.0:
#   Successfully uninstalled torch-2.7.0
# Found existing installation: torchvision 0.22.0
# Uninstalling torchvision-0.22.0:
#   Successfully uninstalled torchvision-0.22.0
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\~-rch'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\~-rchvision'.
# You can safely remove it manually.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch==2.6.0
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Collecting torchvision==0.21.0
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: filelock in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torch==2.6.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torch==2.6.0) (4.12.2)
# Requirement already satisfied: networkx in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torch==2.6.0) (3.3)
# Requirement already satisfied: jinja2 in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torch==2.6.0) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torch==2.6.0) (2024.6.1)
# Collecting sympy==1.13.1 (from torch==2.6.0)
#   Using cached https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Requirement already satisfied: numpy in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torchvision==0.21.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from torchvision==0.21.0) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch==2.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adam\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch==2.6.0) (2.1.5)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-win_amd64.whl (206.5 MB)
#    ---------------------------------------- 0.0/206.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/206.5 MB 3.3 MB/s eta 0:01:03
#    ---------------------------------------- 1.0/206.5 MB 3.6 MB/s eta 0:00:58
#    ---------------------------------------- 1.6/206.5 MB 2.9 MB/s eta 0:01:11
#    ---------------------------------------- 1.8/206.5 MB 2.7 MB/s eta 0:01:16
#     --------------------------------------- 2.6/206.5 MB 2.7 MB/s eta 0:01:15
#     --------------------------------------- 3.1/206.5 MB 2.6 MB/s eta 0:01:18
#     --------------------------------------- 3.7/206.5 MB 2.6 MB/s eta 0:01:19
#     --------------------------------------- 4.2/206.5 MB 2.6 MB/s eta 0:01:19
#     --------------------------------------- 4.7/206.5 MB 2.6 MB/s eta 0:01:19
#    - -------------------------------------- 5.2/206.5 MB 2.5 MB/s eta 0:01:20
#    - -------------------------------------- 5.8/206.5 MB 2.6 MB/s eta 0:01:19
#    - -------------------------------------- 6.3/206.5 MB 2.5 MB/s eta 0:01:20
#    - -------------------------------------- 6.8/206.5 MB 2.5 MB/s eta 0:01:20
#    - -------------------------------------- 7.3/206.5 MB 2.5 MB/s eta 0:01:21
#    - -------------------------------------- 7.9/206.5 MB 2.5 MB/s eta 0:01:19
#    - -------------------------------------- 8.4/206.5 MB 2.5 MB/s eta 0:01:19
#    - -------------------------------------- 8.9/206.5 MB 2.5 MB/s eta 0:01:20
#    - -------------------------------------- 9.4/206.5 MB 2.5 MB/s eta 0:01:18
#    - -------------------------------------- 10.2/206.5 MB 2.6 MB/s eta 0:01:17
#    -- ------------------------------------- 10.7/206.5 MB 2.6 MB/s eta 0:01:16
#    -- ------------------------------------- 11.5/206.5 MB 2.6 MB/s eta 0:01:15
#    -- ------------------------------------- 12.1/206.5 MB 2.6 MB/s eta 0:01:15
#    -- ------------------------------------- 12.6/206.5 MB 2.6 MB/s eta 0:01:15
#    -- ------------------------------------- 13.4/206.5 MB 2.6 MB/s eta 0:01:14
#    -- ------------------------------------- 13.9/206.5 MB 2.6 MB/s eta 0:01:14
#    -- ------------------------------------- 14.4/206.5 MB 2.6 MB/s eta 0:01:13
#    -- ------------------------------------- 15.2/206.5 MB 2.6 MB/s eta 0:01:13
#    -- ------------------------------------- 15.5/206.5 MB 2.6 MB/s eta 0:01:13
#    --- ------------------------------------ 16.0/206.5 MB 2.6 MB/s eta 0:01:13
#    --- ------------------------------------ 16.8/206.5 MB 2.6 MB/s eta 0:01:12
#    --- ------------------------------------ 17.6/206.5 MB 2.7 MB/s eta 0:01:11
#    --- ------------------------------------ 18.1/206.5 MB 2.7 MB/s eta 0:01:11
#    --- ------------------------------------ 18.6/206.5 MB 2.7 MB/s eta 0:01:11
#    --- ------------------------------------ 19.1/206.5 MB 2.7 MB/s eta 0:01:10
#    --- ------------------------------------ 19.7/206.5 MB 2.7 MB/s eta 0:01:10
#    --- ------------------------------------ 20.4/206.5 MB 2.7 MB/s eta 0:01:10
#    ---- ----------------------------------- 21.0/206.5 MB 2.7 MB/s eta 0:01:10
#    ---- ----------------------------------- 21.5/206.5 MB 2.7 MB/s eta 0:01:10
#    ---- ----------------------------------- 22.3/206.5 MB 2.7 MB/s eta 0:01:09
#    ---- ----------------------------------- 22.8/206.5 MB 2.7 MB/s eta 0:01:09
#    ---- ----------------------------------- 23.6/206.5 MB 2.7 MB/s eta 0:01:08
#    ---- ----------------------------------- 24.1/206.5 MB 2.7 MB/s eta 0:01:08
#    ---- ----------------------------------- 24.6/206.5 MB 2.7 MB/s eta 0:01:08
#    ---- ----------------------------------- 25.2/206.5 MB 2.7 MB/s eta 0:01:08
#    ---- ----------------------------------- 25.7/206.5 MB 2.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 26.2/206.5 MB 2.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 26.7/206.5 MB 2.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 27.3/206.5 MB 2.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 28.0/206.5 MB 2.7 MB/s eta 0:01:07
#    ----- ---------------------------------- 28.3/206.5 MB 2.7 MB/s eta 0:01:07
#    ----- ---------------------------------- 28.8/206.5 MB 2.7 MB/s eta 0:01:07
#    ----- ---------------------------------- 29.4/206.5 MB 2.6 MB/s eta 0:01:07
#    ----- ---------------------------------- 29.9/206.5 MB 2.6 MB/s eta 0:01:07
#    ----- ---------------------------------- 30.4/206.5 MB 2.6 MB/s eta 0:01:07
#    ----- ---------------------------------- 30.9/206.5 MB 2.6 MB/s eta 0:01:07
#    ------ --------------------------------- 31.5/206.5 MB 2.6 MB/s eta 0:01:07
#    ------ --------------------------------- 32.0/206.5 MB 2.6 MB/s eta 0:01:07
#    ------ --------------------------------- 32.5/206.5 MB 2.6 MB/s eta 0:01:07
#    ------ --------------------------------- 33.0/206.5 MB 2.6 MB/s eta 0:01:07
#    ------ --------------------------------- 33.6/206.5 MB 2.6 MB/s eta 0:01:06
#    ------ --------------------------------- 34.3/206.5 MB 2.6 MB/s eta 0:01:06
#    ------ --------------------------------- 34.9/206.5 MB 2.6 MB/s eta 0:01:06
#    ------ --------------------------------- 35.1/206.5 MB 2.6 MB/s eta 0:01:06
#    ------- -------------------------------- 36.2/206.5 MB 2.6 MB/s eta 0:01:05
#    ------- -------------------------------- 36.7/206.5 MB 2.6 MB/s eta 0:01:05
#    ------- -------------------------------- 37.0/206.5 MB 2.6 MB/s eta 0:01:05
#    ------- -------------------------------- 37.2/206.5 MB 2.6 MB/s eta 0:01:06
#    ------- -------------------------------- 38.0/206.5 MB 2.6 MB/s eta 0:01:05
#    ------- -------------------------------- 38.5/206.5 MB 2.6 MB/s eta 0:01:05
#    ------- -------------------------------- 39.1/206.5 MB 2.6 MB/s eta 0:01:05
#    ------- -------------------------------- 39.8/206.5 MB 2.6 MB/s eta 0:01:04
#    ------- -------------------------------- 40.4/206.5 MB 2.6 MB/s eta 0:01:04
#    ------- -------------------------------- 40.9/206.5 MB 2.6 MB/s eta 0:01:04
#    -------- ------------------------------- 41.4/206.5 MB 2.6 MB/s eta 0:01:04
#    -------- ------------------------------- 41.9/206.5 MB 2.6 MB/s eta 0:01:04
#    -------- ------------------------------- 42.7/206.5 MB 2.6 MB/s eta 0:01:03
#    -------- ------------------------------- 43.3/206.5 MB 2.6 MB/s eta 0:01:03
#    -------- ------------------------------- 43.8/206.5 MB 2.6 MB/s eta 0:01:02
#    -------- ------------------------------- 44.6/206.5 MB 2.6 MB/s eta 0:01:02
#    -------- ------------------------------- 45.1/206.5 MB 2.6 MB/s eta 0:01:02
#    -------- ------------------------------- 45.4/206.5 MB 2.6 MB/s eta 0:01:02
#    -------- ------------------------------- 46.4/206.5 MB 2.6 MB/s eta 0:01:01
#    --------- ------------------------------ 46.9/206.5 MB 2.6 MB/s eta 0:01:01
#    --------- ------------------------------ 47.4/206.5 MB 2.6 MB/s eta 0:01:01
#    --------- ------------------------------ 48.2/206.5 MB 2.6 MB/s eta 0:01:00
#    --------- ------------------------------ 48.8/206.5 MB 2.6 MB/s eta 0:01:00
#    --------- ------------------------------ 49.3/206.5 MB 2.6 MB/s eta 0:01:00
#    --------- ------------------------------ 50.1/206.5 MB 2.6 MB/s eta 0:01:00
#    --------- ------------------------------ 50.6/206.5 MB 2.6 MB/s eta 0:01:00
#    --------- ------------------------------ 51.1/206.5 MB 2.6 MB/s eta 0:00:59
#    ---------- ----------------------------- 51.6/206.5 MB 2.6 MB/s eta 0:00:59
#    ---------- ----------------------------- 52.4/206.5 MB 2.6 MB/s eta 0:00:59
#    ---------- ----------------------------- 53.2/206.5 MB 2.6 MB/s eta 0:00:58
#    ---------- ----------------------------- 53.7/206.5 MB 2.6 MB/s eta 0:00:58
#    ---------- ----------------------------- 54.0/206.5 MB 2.6 MB/s eta 0:00:58
#    ---------- ----------------------------- 54.5/206.5 MB 2.6 MB/s eta 0:00:58
#    ---------- ----------------------------- 55.3/206.5 MB 2.6 MB/s eta 0:00:58
#    ---------- ----------------------------- 55.8/206.5 MB 2.6 MB/s eta 0:00:58
#    ---------- ----------------------------- 56.6/206.5 MB 2.6 MB/s eta 0:00:57
#    ----------- ---------------------------- 57.1/206.5 MB 2.6 MB/s eta 0:00:57
#    ----------- ---------------------------- 57.7/206.5 MB 2.6 MB/s eta 0:00:57
#    ----------- ---------------------------- 58.5/206.5 MB 2.7 MB/s eta 0:00:56
#    ----------- ---------------------------- 59.0/206.5 MB 2.7 MB/s eta 0:00:56
#    ----------- ---------------------------- 59.5/206.5 MB 2.6 MB/s eta 0:00:56
#    ----------- ---------------------------- 60.3/206.5 MB 2.6 MB/s eta 0:00:56
#    ----------- ---------------------------- 60.8/206.5 MB 2.7 MB/s eta 0:00:55
#    ----------- ---------------------------- 61.3/206.5 MB 2.7 MB/s eta 0:00:55
#    ------------ --------------------------- 62.1/206.5 MB 2.7 MB/s eta 0:00:55
#    ------------ --------------------------- 62.7/206.5 MB 2.7 MB/s eta 0:00:55
#    ------------ --------------------------- 63.2/206.5 MB 2.7 MB/s eta 0:00:54
#    ------------ --------------------------- 63.7/206.5 MB 2.7 MB/s eta 0:00:54
#    ------------ --------------------------- 64.5/206.5 MB 2.7 MB/s eta 0:00:54
#    ------------ --------------------------- 65.0/206.5 MB 2.7 MB/s eta 0:00:54
#    ------------ --------------------------- 65.8/206.5 MB 2.7 MB/s eta 0:00:53
#    ------------ --------------------------- 66.3/206.5 MB 2.7 MB/s eta 0:00:53
#    ------------ --------------------------- 67.1/206.5 MB 2.7 MB/s eta 0:00:53
#    ------------- -------------------------- 67.6/206.5 MB 2.7 MB/s eta 0:00:53
#    ------------- -------------------------- 68.2/206.5 MB 2.7 MB/s eta 0:00:52
#    ------------- -------------------------- 68.4/206.5 MB 2.7 MB/s eta 0:00:53
#    ------------- -------------------------- 69.5/206.5 MB 2.7 MB/s eta 0:00:52
#    ------------- -------------------------- 70.0/206.5 MB 2.7 MB/s eta 0:00:52
#    ------------- -------------------------- 70.5/206.5 MB 2.7 MB/s eta 0:00:52
#    ------------- -------------------------- 71.0/206.5 MB 2.7 MB/s eta 0:00:51
#    ------------- -------------------------- 71.8/206.5 MB 2.7 MB/s eta 0:00:51
#    -------------- ------------------------- 72.4/206.5 MB 2.7 MB/s eta 0:00:51
#    -------------- ------------------------- 72.6/206.5 MB 2.7 MB/s eta 0:00:51
#    -------------- ------------------------- 73.1/206.5 MB 2.7 MB/s eta 0:00:51
#    -------------- ------------------------- 73.7/206.5 MB 2.7 MB/s eta 0:00:51
#    -------------- ------------------------- 74.4/206.5 MB 2.7 MB/s eta 0:00:50
#    -------------- ------------------------- 75.0/206.5 MB 2.7 MB/s eta 0:00:50
#    -------------- ------------------------- 75.8/206.5 MB 2.7 MB/s eta 0:00:50
#    -------------- ------------------------- 76.0/206.5 MB 2.7 MB/s eta 0:00:50
#    -------------- ------------------------- 76.8/206.5 MB 2.7 MB/s eta 0:00:49
#    -------------- ------------------------- 77.1/206.5 MB 2.7 MB/s eta 0:00:49
#    --------------- ------------------------ 77.9/206.5 MB 2.7 MB/s eta 0:00:49
#    --------------- ------------------------ 78.6/206.5 MB 2.7 MB/s eta 0:00:49
#    --------------- ------------------------ 79.2/206.5 MB 2.7 MB/s eta 0:00:48
#    --------------- ------------------------ 79.7/206.5 MB 2.7 MB/s eta 0:00:48
#    --------------- ------------------------ 80.2/206.5 MB 2.6 MB/s eta 0:00:48
#    --------------- ------------------------ 80.7/206.5 MB 2.6 MB/s eta 0:00:48
#    --------------- ------------------------ 81.3/206.5 MB 2.7 MB/s eta 0:00:48
#    --------------- ------------------------ 81.8/206.5 MB 2.7 MB/s eta 0:00:47
#    --------------- ------------------------ 82.3/206.5 MB 2.6 MB/s eta 0:00:47
#    ---------------- ----------------------- 82.8/206.5 MB 2.6 MB/s eta 0:00:47
#    ---------------- ----------------------- 83.4/206.5 MB 2.6 MB/s eta 0:00:47
#    ---------------- ----------------------- 83.9/206.5 MB 2.6 MB/s eta 0:00:47
#    ---------------- ----------------------- 84.1/206.5 MB 2.6 MB/s eta 0:00:47
#    ---------------- ----------------------- 84.7/206.5 MB 2.6 MB/s eta 0:00:47
#    ---------------- ----------------------- 85.5/206.5 MB 2.6 MB/s eta 0:00:46
#    ---------------- ----------------------- 85.7/206.5 MB 2.6 MB/s eta 0:00:46
#    ---------------- ----------------------- 86.2/206.5 MB 2.6 MB/s eta 0:00:46
#    ---------------- ----------------------- 86.5/206.5 MB 2.6 MB/s eta 0:00:46
#    ---------------- ----------------------- 87.0/206.5 MB 2.6 MB/s eta 0:00:46
#    ---------------- ----------------------- 87.6/206.5 MB 2.6 MB/s eta 0:00:46
#    ----------------- ---------------------- 88.3/206.5 MB 2.6 MB/s eta 0:00:46
#    ----------------- ---------------------- 88.6/206.5 MB 2.6 MB/s eta 0:00:46
#    ----------------- ---------------------- 89.4/206.5 MB 2.6 MB/s eta 0:00:45
#    ----------------- ---------------------- 89.9/206.5 MB 2.6 MB/s eta 0:00:45
#    ----------------- ---------------------- 90.2/206.5 MB 2.6 MB/s eta 0:00:45
#    ----------------- ---------------------- 91.2/206.5 MB 2.6 MB/s eta 0:00:45
#    ----------------- ---------------------- 91.8/206.5 MB 2.6 MB/s eta 0:00:44
#    ----------------- ---------------------- 92.5/206.5 MB 2.6 MB/s eta 0:00:44
#    ------------------ --------------------- 93.1/206.5 MB 2.6 MB/s eta 0:00:44
#    ------------------ --------------------- 93.8/206.5 MB 2.6 MB/s eta 0:00:44
#    ------------------ --------------------- 94.4/206.5 MB 2.6 MB/s eta 0:00:43
#    ------------------ --------------------- 94.9/206.5 MB 2.6 MB/s eta 0:00:43
#    ------------------ --------------------- 95.7/206.5 MB 2.6 MB/s eta 0:00:43
#    ------------------ --------------------- 96.2/206.5 MB 2.6 MB/s eta 0:00:43
#    ------------------ --------------------- 96.7/206.5 MB 2.6 MB/s eta 0:00:43
#    ------------------ --------------------- 97.5/206.5 MB 2.6 MB/s eta 0:00:42
#    ------------------ --------------------- 98.0/206.5 MB 2.6 MB/s eta 0:00:42
#    ------------------- -------------------- 98.6/206.5 MB 2.6 MB/s eta 0:00:42
#    ------------------- -------------------- 99.4/206.5 MB 2.6 MB/s eta 0:00:42
#    ------------------- -------------------- 99.9/206.5 MB 2.6 MB/s eta 0:00:41
#    ------------------- -------------------- 100.7/206.5 MB 2.6 MB/s eta 0:00:41
#    ------------------- -------------------- 101.2/206.5 MB 2.6 MB/s eta 0:00:41
#    ------------------- -------------------- 101.4/206.5 MB 2.6 MB/s eta 0:00:41
#    ------------------- -------------------- 102.5/206.5 MB 2.6 MB/s eta 0:00:40
#    ------------------- -------------------- 103.0/206.5 MB 2.6 MB/s eta 0:00:40
#    -------------------- ------------------- 103.5/206.5 MB 2.6 MB/s eta 0:00:40
#    -------------------- ------------------- 104.1/206.5 MB 2.6 MB/s eta 0:00:40
#    -------------------- ------------------- 104.9/206.5 MB 2.6 MB/s eta 0:00:39
#    -------------------- ------------------- 105.4/206.5 MB 2.6 MB/s eta 0:00:39
#    -------------------- ------------------- 106.2/206.5 MB 2.6 MB/s eta 0:00:39
#    -------------------- ------------------- 106.7/206.5 MB 2.6 MB/s eta 0:00:39
#    -------------------- ------------------- 107.2/206.5 MB 2.6 MB/s eta 0:00:38
#    -------------------- ------------------- 107.7/206.5 MB 2.6 MB/s eta 0:00:38
#    -------------------- ------------------- 108.3/206.5 MB 2.6 MB/s eta 0:00:38
#    --------------------- ------------------ 108.8/206.5 MB 2.6 MB/s eta 0:00:38
#    --------------------- ------------------ 109.3/206.5 MB 2.6 MB/s eta 0:00:38
#    --------------------- ------------------ 109.8/206.5 MB 2.6 MB/s eta 0:00:37
#    --------------------- ------------------ 110.6/206.5 MB 2.6 MB/s eta 0:00:37
#    --------------------- ------------------ 111.1/206.5 MB 2.6 MB/s eta 0:00:37
#    --------------------- ------------------ 111.7/206.5 MB 2.6 MB/s eta 0:00:37
#    --------------------- ------------------ 112.2/206.5 MB 2.6 MB/s eta 0:00:36
#    --------------------- ------------------ 113.0/206.5 MB 2.6 MB/s eta 0:00:36
#    --------------------- ------------------ 113.2/206.5 MB 2.6 MB/s eta 0:00:36
#    ---------------------- ----------------- 114.0/206.5 MB 2.6 MB/s eta 0:00:36
#    ---------------------- ----------------- 114.6/206.5 MB 2.6 MB/s eta 0:00:36
#    ---------------------- ----------------- 115.3/206.5 MB 2.6 MB/s eta 0:00:35
#    ---------------------- ----------------- 115.9/206.5 MB 2.6 MB/s eta 0:00:35
#    ---------------------- ----------------- 116.4/206.5 MB 2.6 MB/s eta 0:00:35
#    ---------------------- ----------------- 116.7/206.5 MB 2.6 MB/s eta 0:00:35
#    ---------------------- ----------------- 117.7/206.5 MB 2.6 MB/s eta 0:00:34
#    ---------------------- ----------------- 118.2/206.5 MB 2.6 MB/s eta 0:00:34
#    ---------------------- ----------------- 118.8/206.5 MB 2.6 MB/s eta 0:00:34
#    ----------------------- ---------------- 119.5/206.5 MB 2.6 MB/s eta 0:00:34
#    ----------------------- ---------------- 119.8/206.5 MB 2.6 MB/s eta 0:00:33
#    ----------------------- ---------------- 120.6/206.5 MB 2.6 MB/s eta 0:00:33
#    ----------------------- ---------------- 121.4/206.5 MB 2.6 MB/s eta 0:00:33
#    ----------------------- ---------------- 121.9/206.5 MB 2.6 MB/s eta 0:00:33
#    ----------------------- ---------------- 122.4/206.5 MB 2.6 MB/s eta 0:00:32
#    ----------------------- ---------------- 122.7/206.5 MB 2.6 MB/s eta 0:00:32
#    ----------------------- ---------------- 123.5/206.5 MB 2.6 MB/s eta 0:00:32
#    ------------------------ --------------- 124.0/206.5 MB 2.6 MB/s eta 0:00:32
#    ------------------------ --------------- 124.5/206.5 MB 2.6 MB/s eta 0:00:32
#    ------------------------ --------------- 125.0/206.5 MB 2.6 MB/s eta 0:00:32
#    ------------------------ --------------- 125.6/206.5 MB 2.6 MB/s eta 0:00:31
#    ------------------------ --------------- 126.1/206.5 MB 2.6 MB/s eta 0:00:31
#    ------------------------ --------------- 126.6/206.5 MB 2.6 MB/s eta 0:00:31
#    ------------------------ --------------- 127.4/206.5 MB 2.6 MB/s eta 0:00:31
#    ------------------------ --------------- 127.9/206.5 MB 2.6 MB/s eta 0:00:31
#    ------------------------ --------------- 128.5/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------ --------------- 128.7/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------- -------------- 129.2/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------- -------------- 129.8/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------- -------------- 130.3/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------- -------------- 130.8/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------- -------------- 131.3/206.5 MB 2.6 MB/s eta 0:00:30
#    ------------------------- -------------- 131.9/206.5 MB 2.6 MB/s eta 0:00:29
#    ------------------------- -------------- 132.6/206.5 MB 2.6 MB/s eta 0:00:29
#    ------------------------- -------------- 133.4/206.5 MB 2.6 MB/s eta 0:00:29
#    ------------------------- -------------- 134.0/206.5 MB 2.6 MB/s eta 0:00:28
#    ------------------------- -------------- 134.2/206.5 MB 2.6 MB/s eta 0:00:28
#    -------------------------- ------------- 134.5/206.5 MB 2.6 MB/s eta 0:00:28
#    -------------------------- ------------- 135.5/206.5 MB 2.6 MB/s eta 0:00:28
#    -------------------------- ------------- 136.1/206.5 MB 2.6 MB/s eta 0:00:28
#    -------------------------- ------------- 136.6/206.5 MB 2.6 MB/s eta 0:00:28
#    -------------------------- ------------- 136.8/206.5 MB 2.6 MB/s eta 0:00:28
#    -------------------------- ------------- 137.4/206.5 MB 2.6 MB/s eta 0:00:27
#    -------------------------- ------------- 137.9/206.5 MB 2.6 MB/s eta 0:00:27
#    -------------------------- ------------- 138.4/206.5 MB 2.6 MB/s eta 0:00:27
#    -------------------------- ------------- 138.9/206.5 MB 2.6 MB/s eta 0:00:27
#    --------------------------- ------------ 139.5/206.5 MB 2.6 MB/s eta 0:00:27
#    --------------------------- ------------ 139.7/206.5 MB 2.6 MB/s eta 0:00:27
#    --------------------------- ------------ 140.2/206.5 MB 2.5 MB/s eta 0:00:27
#    --------------------------- ------------ 140.5/206.5 MB 2.5 MB/s eta 0:00:27
#    --------------------------- ------------ 141.0/206.5 MB 2.5 MB/s eta 0:00:26
#    --------------------------- ------------ 141.6/206.5 MB 2.5 MB/s eta 0:00:26
#    --------------------------- ------------ 141.8/206.5 MB 2.5 MB/s eta 0:00:26
#    --------------------------- ------------ 142.3/206.5 MB 2.5 MB/s eta 0:00:26
#    --------------------------- ------------ 142.9/206.5 MB 2.5 MB/s eta 0:00:26
#    --------------------------- ------------ 143.4/206.5 MB 2.5 MB/s eta 0:00:26
#    --------------------------- ------------ 143.9/206.5 MB 2.5 MB/s eta 0:00:25
#    --------------------------- ------------ 144.2/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 144.7/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 145.2/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 145.8/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 146.0/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 146.3/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 146.8/206.5 MB 2.5 MB/s eta 0:00:25
#    ---------------------------- ----------- 147.3/206.5 MB 2.5 MB/s eta 0:00:24
#    ---------------------------- ----------- 147.8/206.5 MB 2.5 MB/s eta 0:00:24
#    ---------------------------- ----------- 148.4/206.5 MB 2.5 MB/s eta 0:00:24
#    ---------------------------- ----------- 148.9/206.5 MB 2.5 MB/s eta 0:00:24
#    ---------------------------- ----------- 149.4/206.5 MB 2.5 MB/s eta 0:00:24
#    ---------------------------- ----------- 149.7/206.5 MB 2.5 MB/s eta 0:00:24
#    ----------------------------- ---------- 150.2/206.5 MB 2.5 MB/s eta 0:00:23
#    ----------------------------- ---------- 151.0/206.5 MB 2.5 MB/s eta 0:00:23
#    ----------------------------- ---------- 151.3/206.5 MB 2.4 MB/s eta 0:00:23
#    ----------------------------- ---------- 151.8/206.5 MB 2.4 MB/s eta 0:00:23
#    ----------------------------- ---------- 152.3/206.5 MB 2.4 MB/s eta 0:00:23
#    ----------------------------- ---------- 152.8/206.5 MB 2.4 MB/s eta 0:00:23
#    ----------------------------- ---------- 153.1/206.5 MB 2.4 MB/s eta 0:00:22
#    ----------------------------- ---------- 153.6/206.5 MB 2.4 MB/s eta 0:00:22
#    ----------------------------- ---------- 154.1/206.5 MB 2.4 MB/s eta 0:00:22
#    ----------------------------- ---------- 154.7/206.5 MB 2.4 MB/s eta 0:00:22
#    ------------------------------ --------- 154.9/206.5 MB 2.4 MB/s eta 0:00:22
#    ------------------------------ --------- 155.2/206.5 MB 2.4 MB/s eta 0:00:22
#    ------------------------------ --------- 155.7/206.5 MB 2.4 MB/s eta 0:00:22
#    ------------------------------ --------- 156.2/206.5 MB 2.4 MB/s eta 0:00:21
#    ------------------------------ --------- 156.8/206.5 MB 2.4 MB/s eta 0:00:21
#    ------------------------------ --------- 157.0/206.5 MB 2.4 MB/s eta 0:00:21
#    ------------------------------ --------- 157.5/206.5 MB 2.4 MB/s eta 0:00:21
#    ------------------------------ --------- 157.8/206.5 MB 2.4 MB/s eta 0:00:21
#    ------------------------------ --------- 158.3/206.5 MB 2.4 MB/s eta 0:00:21
#    ------------------------------ --------- 158.9/206.5 MB 2.4 MB/s eta 0:00:20
#    ------------------------------ --------- 159.4/206.5 MB 2.4 MB/s eta 0:00:20
#    ------------------------------ --------- 159.9/206.5 MB 2.4 MB/s eta 0:00:20
#    ------------------------------- -------- 160.4/206.5 MB 2.4 MB/s eta 0:00:20
#    ------------------------------- -------- 160.7/206.5 MB 2.4 MB/s eta 0:00:20
#    ------------------------------- -------- 161.2/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 161.5/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 162.3/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 162.5/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 163.1/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 163.6/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 163.8/206.5 MB 2.4 MB/s eta 0:00:19
#    ------------------------------- -------- 164.4/206.5 MB 2.4 MB/s eta 0:00:18
#    ------------------------------- -------- 164.6/206.5 MB 2.4 MB/s eta 0:00:18
#    -------------------------------- ------- 165.4/206.5 MB 2.4 MB/s eta 0:00:18
#    -------------------------------- ------- 165.9/206.5 MB 2.3 MB/s eta 0:00:18
#    -------------------------------- ------- 166.5/206.5 MB 2.3 MB/s eta 0:00:18
#    -------------------------------- ------- 166.7/206.5 MB 2.3 MB/s eta 0:00:18
#    -------------------------------- ------- 167.5/206.5 MB 2.3 MB/s eta 0:00:17
#    -------------------------------- ------- 167.8/206.5 MB 2.3 MB/s eta 0:00:17
#    -------------------------------- ------- 168.6/206.5 MB 2.3 MB/s eta 0:00:17
#    -------------------------------- ------- 169.1/206.5 MB 2.3 MB/s eta 0:00:17
#    -------------------------------- ------- 169.3/206.5 MB 2.3 MB/s eta 0:00:16
#    -------------------------------- ------- 170.1/206.5 MB 2.3 MB/s eta 0:00:16
#    --------------------------------- ------ 170.7/206.5 MB 2.3 MB/s eta 0:00:16
#    --------------------------------- ------ 170.9/206.5 MB 2.3 MB/s eta 0:00:16
#    --------------------------------- ------ 171.4/206.5 MB 2.3 MB/s eta 0:00:16
#    --------------------------------- ------ 172.2/206.5 MB 2.3 MB/s eta 0:00:15
#    --------------------------------- ------ 172.8/206.5 MB 2.3 MB/s eta 0:00:15
#    --------------------------------- ------ 173.3/206.5 MB 2.3 MB/s eta 0:00:15
#    --------------------------------- ------ 173.8/206.5 MB 2.3 MB/s eta 0:00:15
#    --------------------------------- ------ 174.3/206.5 MB 2.3 MB/s eta 0:00:15
#    --------------------------------- ------ 174.9/206.5 MB 2.3 MB/s eta 0:00:14
#    --------------------------------- ------ 175.1/206.5 MB 2.3 MB/s eta 0:00:14
#    ---------------------------------- ----- 175.9/206.5 MB 2.3 MB/s eta 0:00:14
#    ---------------------------------- ----- 176.4/206.5 MB 2.3 MB/s eta 0:00:14
#    ---------------------------------- ----- 176.7/206.5 MB 2.3 MB/s eta 0:00:14
#    ---------------------------------- ----- 177.2/206.5 MB 2.3 MB/s eta 0:00:13
#    ---------------------------------- ----- 177.7/206.5 MB 2.3 MB/s eta 0:00:13
#    ---------------------------------- ----- 178.3/206.5 MB 2.3 MB/s eta 0:00:13
#    ---------------------------------- ----- 178.8/206.5 MB 2.3 MB/s eta 0:00:13
#    ---------------------------------- ----- 179.3/206.5 MB 2.3 MB/s eta 0:00:12
#    ---------------------------------- ----- 179.6/206.5 MB 2.3 MB/s eta 0:00:12
#    ---------------------------------- ----- 180.1/206.5 MB 2.3 MB/s eta 0:00:12
#    ---------------------------------- ----- 180.6/206.5 MB 2.3 MB/s eta 0:00:12
#    ----------------------------------- ---- 181.4/206.5 MB 2.3 MB/s eta 0:00:12
#    ----------------------------------- ---- 181.9/206.5 MB 2.3 MB/s eta 0:00:11
#    ----------------------------------- ---- 182.5/206.5 MB 2.3 MB/s eta 0:00:11
#    ----------------------------------- ---- 183.0/206.5 MB 2.3 MB/s eta 0:00:11
#    ----------------------------------- ---- 183.5/206.5 MB 2.3 MB/s eta 0:00:11
#    ----------------------------------- ---- 184.0/206.5 MB 2.3 MB/s eta 0:00:10
#    ----------------------------------- ---- 184.8/206.5 MB 2.3 MB/s eta 0:00:10
#    ----------------------------------- ---- 185.3/206.5 MB 2.3 MB/s eta 0:00:10
#    ----------------------------------- ---- 185.9/206.5 MB 2.3 MB/s eta 0:00:10
#    ------------------------------------ --- 186.4/206.5 MB 2.3 MB/s eta 0:00:09
#    ------------------------------------ --- 186.9/206.5 MB 2.3 MB/s eta 0:00:09
#    ------------------------------------ --- 187.4/206.5 MB 2.3 MB/s eta 0:00:09
#    ------------------------------------ --- 188.0/206.5 MB 2.3 MB/s eta 0:00:09
#    ------------------------------------ --- 188.5/206.5 MB 2.3 MB/s eta 0:00:09
#    ------------------------------------ --- 189.0/206.5 MB 2.3 MB/s eta 0:00:08
#    ------------------------------------ --- 189.5/206.5 MB 2.2 MB/s eta 0:00:08
#    ------------------------------------ --- 190.1/206.5 MB 2.2 MB/s eta 0:00:08
#    ------------------------------------ --- 190.8/206.5 MB 2.3 MB/s eta 0:00:07
#    ------------------------------------- -- 191.4/206.5 MB 2.3 MB/s eta 0:00:07
#    ------------------------------------- -- 191.9/206.5 MB 2.2 MB/s eta 0:00:07
#    ------------------------------------- -- 192.4/206.5 MB 2.3 MB/s eta 0:00:07
#    ------------------------------------- -- 192.9/206.5 MB 2.3 MB/s eta 0:00:07
#    ------------------------------------- -- 193.2/206.5 MB 2.2 MB/s eta 0:00:06
#    ------------------------------------- -- 193.7/206.5 MB 2.2 MB/s eta 0:00:06
#    ------------------------------------- -- 193.7/206.5 MB 2.2 MB/s eta 0:00:06
#    ------------------------------------- -- 194.8/206.5 MB 2.2 MB/s eta 0:00:06
#    ------------------------------------- -- 195.0/206.5 MB 2.2 MB/s eta 0:00:06
#    ------------------------------------- -- 195.6/206.5 MB 2.2 MB/s eta 0:00:05
#    ------------------------------------- -- 195.6/206.5 MB 2.2 MB/s eta 0:00:05
#    ------------------------------------- -- 196.1/206.5 MB 2.2 MB/s eta 0:00:05
#    -------------------------------------- - 196.6/206.5 MB 2.2 MB/s eta 0:00:05
#    -------------------------------------- - 197.1/206.5 MB 2.2 MB/s eta 0:00:05
#    -------------------------------------- - 197.7/206.5 MB 2.2 MB/s eta 0:00:05
#    -------------------------------------- - 198.2/206.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------------------- - 198.4/206.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------------------- - 199.5/206.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------------------- - 199.8/206.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------------------- - 200.0/206.5 MB 2.2 MB/s eta 0:00:03
#    -------------------------------------- - 201.1/206.5 MB 2.2 MB/s eta 0:00:03
#    -------------------------------------- - 201.3/206.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------------------------  202.1/206.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------------------------  202.6/206.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------------  202.9/206.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------------  203.4/206.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------------  204.2/206.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------------  204.5/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  205.0/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  205.5/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  206.3/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  206.3/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  206.3/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  206.3/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  206.3/206.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 206.5/206.5 MB 2.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.5 MB/s eta 0:00:00
# Installing collected packages: sympy, torch, torchvision
#
#   Attempting uninstall: sympy
#
#     Found existing installation: sympy 1.14.0
#
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#     Uninstalling sympy-1.14.0:
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#       Successfully uninstalled sympy-1.14.0
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
# ...
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.1 requires torch==2.3.1, but you have torch 2.6.0+cpu which is incompatible.
# vllm 0.6.2 requires torch==2.4.0, but you have torch 2.6.0+cpu which is incompatible.
# vllm 0.6.2 requires torchvision==0.19, but you have torchvision 0.21.0+cpu which is incompatible.
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    ---------------------------------------- 3/3 [torchvision]
#
# Successfully installed sympy-1.13.1 torch-2.6.0+cpu torchvision-0.21.0+cpu
